# %% [markdown]
# # Exploratory Data Analysis on Terrorismset - Terrorism
#
# ** Author- Rushikesh Subhash Dolas **

# %%
# importing the libraries related to the Data manipulation.
import numpy as np
import pandas as pd
    
# importing the libraries related to the Data_visualization
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# Datapath = E:\DOWNLOADS\globalterrorismdb_0718dist.csv
Terrorism = pd.read_csv(r'E:\DOWNLOADS\globalterrorismdb_0718dist.csv')
Terrorism.head()
# Out:
# C:\Users\SAMARTH P SHET\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3165: DtypeWarning: Columns (4,6,31,33,61,62,63,76,79,90,92,94,96,114,115,121) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# ...

# %%
Terrorism.tail()
# Out:
#              eventid  iyear  imonth  iday approxdate  extended resolution  \
# 181686  201712310022   2017      12    31        NaN         0        NaN
# 181687  201712310029   2017      12    31        NaN         0        NaN
# 181688  201712310030   2017      12    31        NaN         0        NaN
# 181689  201712310031   2017      12    31        NaN         0        NaN
# 181690  201712310032   2017      12    31        NaN         0        NaN
#
#         country  country_txt  region  ... addnotes  \
# 181686      182      Somalia      11  ...      NaN
# 181687      200        Syria      10  ...      NaN
# 181688      160  Philippines       5  ...      NaN
# 181689       92        India       6  ...      NaN
# 181690      160  Philippines       5  ...      NaN
#
#                                                    scite1  \
# 181686  "Somalia: Al-Shabaab Militants Attack Army Che...
# 181687  "Putin's 'victory' in Syria has turned into a ...
# ...

# %%
Terrorism.shape
# Out:
# (181691, 135)

# %%
Terrorism.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 181691 entries, 0 to 181690
# Columns: 135 entries, eventid to related
# dtypes: float64(55), int64(22), object(58)
# memory usage: 187.1+ MB

# %%
Terrorism.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# approxdate    172452
#                ...
# INT_LOG            0
# INT_IDEO           0
# INT_MISC           0
# INT_ANY            0
# related       156653
# Length: 135, dtype: int64

# %%
plt.figure(figsize=(25,5))
sns.heatmap(Terrorism.isnull(),yticklabels=False)
plt.title("Heatmap showing the null values present in dataframe-Terrorism")
# Out:
# Text(0.5, 1.0, 'Heatmap showing the null values present in dataframe-Terrorism')

# %% [markdown]
# ### From the above output, we can see above most have the columns have missing vales of more than 50%¶

# %% [markdown]
# ### To find the exact number,Now we will check the percentage of nan values present in each feature

# %%
# list of features which has missing values
features_with_na=[features for features in Terrorism.columns if Terrorism[features].isnull().sum()>1]

# print the feature name and the percentage of missing values
for feature in features_with_na:
    print(feature, np.round(Terrorism[feature].isnull().mean(), 4),  ' % missing values')
# Out:
# approxdate 0.9491  % missing values
# resolution 0.9878  % missing values
# provstate 0.0023  % missing values
# city 0.0024  % missing values
# latitude 0.0251  % missing values
# longitude 0.0251  % missing values
# specificity 0.0  % missing values
# location 0.6946  % missing values
# summary 0.364  % missing values
# alternative 0.8403  % missing values
# alternative_txt 0.8403  % missing values
# attacktype2 0.9652  % missing values
# attacktype2_txt 0.9652  % missing values
# attacktype3 0.9976  % missing values
# attacktype3_txt 0.9976  % missing values
# targsubtype1 0.0571  % missing values
# targsubtype1_txt 0.0571  % missing values
# corp1 0.2342  % missing values
# target1 0.0035  % missing values
# natlty1 0.0086  % missing values
# natlty1_txt 0.0086  % missing values
# targtype2 0.9387  % missing values
# targtype2_txt 0.9387  % missing values
# targsubtype2 0.9412  % missing values
# targsubtype2_txt 0.9412  % missing values
# corp2 0.9443  % missing values
# ...

# %%
Terrorism.describe()
# Out:
#             eventid          iyear         imonth           iday  \
# count  1.816910e+05  181691.000000  181691.000000  181691.000000
# mean   2.002705e+11    2002.638997       6.467277      15.505644
# std    1.325957e+09      13.259430       3.388303       8.814045
# min    1.970000e+11    1970.000000       0.000000       0.000000
# 25%    1.991021e+11    1991.000000       4.000000       8.000000
# 50%    2.009022e+11    2009.000000       6.000000      15.000000
# 75%    2.014081e+11    2014.000000       9.000000      23.000000
# max    2.017123e+11    2017.000000      12.000000      31.000000
#
#             extended        country         region       latitude  \
# count  181691.000000  181691.000000  181691.000000  177135.000000
# mean        0.045346     131.968501       7.160938      23.498343
# std         0.208063     112.414535       2.933408      18.569242
# min         0.000000       4.000000       1.000000     -53.154613
# ...

# %%
Terrorism.duplicated().sum()
# Out:
# 0

# %%
corr = Terrorism.corr()
plt.figure(figsize=(15,15))
sns.heatmap(data= corr, cmap="YlGnBu")
plt.show()

# %%
plt.close()

# %% [markdown]
# ## Thank you!!
